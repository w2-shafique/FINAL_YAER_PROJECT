# %% [markdown]
# <a href="https://colab.research.google.com/github/w2-shafique/FINAL_YAER_PROJECT/blob/main/GOLD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Gold_df = pd.read_csv('Gold Futures Historical Data-10.csv')

# %%
Gold_df = Gold_df.dropna(subset=['Vol.']).reset_index(drop=True)

# %%
import pandas as pd

# ✅ Rename columns for simplicity (optional but cleaner)
Gold_df.columns = ['Date', 'Close', 'Open', 'High', 'Low', 'Vol', 'Change']

# ✅ Convert Date to datetime format and sort ascending
Gold_df['Date'] = pd.to_datetime(Gold_df['Date'])
Gold_df = Gold_df.sort_values('Date')

# ✅ Remove commas and convert price columns to float
for col in ['Close', 'Open', 'High', 'Low']:
    Gold_df[col] = Gold_df[col].replace(',', '', regex=True).astype(float)

# ✅ Convert Volume (Vol) from K/M to numeric values
def convert_volume(vol):
    if isinstance(vol, str):
        if 'K' in vol:
            return float(vol.replace('K', '')) * 1_000
        elif 'M' in vol:
            return float(vol.replace('M', '')) * 1_000_000
        elif vol == '-' or vol.strip() == '':
            return None
        else:
            return float(vol)
    return vol

Gold_df['Vol'] = Gold_df['Vol'].apply(convert_volume)

# ✅ Clean 'Change' column (remove % and convert to float)
Gold_df['Change'] = Gold_df['Change'].str.replace('%', '', regex=True).astype(float)

# %%
Gold_df.isnull().sum()
# Out:
# Date      0
# Close     0
# Open      0
# High      0
# Low       0
# Vol       0
# Change    0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import os, random

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# %%
Gold_df['return'] = np.log(Gold_df['Close'] / Gold_df['Close'].shift(1))
Gold_df = Gold_df.dropna()

# %%
# !pip install arch
# Out:
# Requirement already satisfied: arch in /usr/local/lib/python3.12/dist-packages (8.0.0)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from arch) (2.0.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from arch) (2.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from arch) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from arch) (0.14.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arch) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->arch) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->arch) (1.17.0)

# %%
  from arch import arch_model

model = arch_model(
    Gold_df['return'] * 100,   # scale returns for stability
    vol='EGARCH',
    p=1, o=1, q=1,
    dist='normal'
)

res = model.fit(disp='off')
print(res.summary())
# Out:
#                      Constant Mean - EGARCH Model Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                     EGARCH   Log-Likelihood:               -2732.51
# Distribution:                  Normal   AIC:                           5475.02
# Method:            Maximum Likelihood   BIC:                           5503.12
#                                         No. Observations:                 2039
# Date:                Mon, Dec 08 2025   Df Residuals:                     2038
# Time:                        17:19:35   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0443  1.986e-02      2.229  2.580e-02 [5.349e-03,8.322e-02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      3.4142e-03  3.691e-03      0.925      0.355 [-3.820e-03,1.065e-02]
# alpha[1]       0.1157  2.912e-02      3.973  7.083e-05    [5.863e-02,  0.173]
# gamma[1]       0.0538  1.643e-02      3.276  1.054e-03  [2.162e-02,8.603e-02]
# beta[1]        0.9702  9.315e-03    104.151      0.000      [  0.952,  0.988]
# =============================================================================
#
# Covariance estimator: robust

# %%
Gold_df['egarch_vol'] = res.conditional_volatility

# %%
Gold_df['egarch_vol'].plot(figsize=(12,5), title="EGARCH Conditional Volatility")
# Out:
# <Axes: title={'center': 'EGARCH Conditional Volatility'}>

# %%
import numpy as np
import pandas as pd

# 1. Make sure data is sorted by date
Gold_df = Gold_df.sort_values('Date').reset_index(drop=True)

# 2. Smooth EGARCH volatility (5-day EWM, you can try 7 or 10 later)
Gold_df['egarch_vol_ewm'] = Gold_df['egarch_vol'].ewm(span=7, adjust=False).mean()

# 3. Log-transform the smoothed volatility to stabilise scale
Gold_df['log_egarch_vol_ewm'] = np.log(Gold_df['egarch_vol_ewm'] + 1e-6)

# 4. Keep only non-null rows for these columns
Gold_df = Gold_df.dropna(subset=['Close', 'Vol', 'log_egarch_vol_ewm'])

Gold_df[['Date', 'Close', 'Vol', 'egarch_vol', 'egarch_vol_ewm', 'log_egarch_vol_ewm']].head()
# Out:
#         Date   Close       Vol  egarch_vol  egarch_vol_ewm  log_egarch_vol_ewm
# 0 2018-01-03  1318.5  353460.0    0.586492        0.586492           -0.533594
# 1 2018-01-04  1321.6  369850.0    0.581461        0.585234           -0.535741
# 2 2018-01-05  1322.3  330230.0    0.581163        0.584217           -0.537482
# 3 2018-01-08  1320.4  246090.0    0.565676        0.579581           -0.545447
# 4 2018-01-09  1313.7  333530.0    0.556038        0.573695           -0.555655

# %%
# Make sure Gold_df has 'Close' ,'Vol' ,'Vol','log_egarch_vol_ewm'
data = Gold_df[['Close', 'Vol','log_egarch_vol_ewm']].dropna().values  # shape (N, 3)

window_size = 14   # you can tune this
n = len(data)
print("Total rows:", n)

# Time-based 80/10/10 split
train_end = int(n * 0.8)
val_end   = int(n * 0.9)

train_raw = data[:train_end]
val_raw   = data[train_end - window_size : val_end]   # include overlap
test_raw  = data[val_end - window_size :]             # include overlap

print("Train raw:", train_raw.shape)
print("Val raw  :", val_raw.shape)
print("Test raw :", test_raw.shape)
# Out:
# Total rows: 2039
# Train raw: (1631, 3)
# Val raw  : (218, 3)
# Test raw : (218, 3)

# %%
def create_sequences(X_data, y_data, window_size=14):
    """
    X_data: (N, n_features)
    y_data: (N, 1)
    Returns:
      X: (num_samples, window_size, n_features)
      y: (num_samples, 1)
    """
    X, y = [], []
    for i in range(window_size, len(X_data)):
        X.append(X_data[i-window_size:i])
        y.append(y_data[i])
    return np.array(X), np.array(y)

# %%
# Feature scaler (Close + Vol +'log_egarch_vol_ewm')
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(train_raw)
X_val_scaled   = X_scaler.transform(val_raw)
X_test_scaled  = X_scaler.transform(test_raw)

# Target scaler (Close only)
y_scaler = MinMaxScaler()

close_train = train_raw[:, 0].reshape(-1, 1)
close_val   = val_raw[:, 0].reshape(-1, 1)
close_test  = test_raw[:, 0].reshape(-1, 1)

y_train_scaled_full = y_scaler.fit_transform(close_train)
y_val_scaled_full   = y_scaler.transform(close_val)
y_test_scaled_full  = y_scaler.transform(close_test)

# %%
X_tr, y_tr = create_sequences(X_train_scaled, y_train_scaled_full, window_size)
X_val, y_val = create_sequences(X_val_scaled, y_val_scaled_full, window_size)
X_te, y_te = create_sequences(X_test_scaled, y_test_scaled_full, window_size)

print("Train seq:", X_tr.shape, y_tr.shape)
print("Val seq  :", X_val.shape, y_val.shape)
print("Test seq :", X_te.shape, y_te.shape)
# Out:
# Train seq: (1617, 14, 3) (1617, 1)
# Val seq  : (204, 14, 3) (204, 1)
# Test seq : (204, 14, 3) (204, 1)

# %%
# Feature scaler ((Close + Vol +'log_egarch_vol_ewm')
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(train_raw)
X_val_scaled   = X_scaler.transform(val_raw)
X_test_scaled  = X_scaler.transform(test_raw)

# Target scaler (Close only)
y_scaler = MinMaxScaler()

close_train = train_raw[:, 0].reshape(-1, 1)
close_val   = val_raw[:, 0].reshape(-1, 1)
close_test  = test_raw[:, 0].reshape(-1, 1)

y_train_scaled_full = y_scaler.fit_transform(close_train)
y_val_scaled_full   = y_scaler.transform(close_val)
y_test_scaled_full  = y_scaler.transform(close_test)

# %%
def train_lstm_once(
    X_tr, y_tr, X_val, y_val, X_te, y_te, y_scaler,
    epochs=30, batch_size=32, seed=None
):
    tf.keras.backend.clear_session()

    if seed is not None:
        seed = int(seed)   # FIX

        np.random.seed(seed)
        random.seed(seed)
        tf.random.set_seed(seed)
        os.environ["PYTHONHASHSEED"] = str(seed)
        os.environ["TF_DETERMINISTIC_OPS"] = "1"

    model = Sequential([
        LSTM(64, return_sequences=False, input_shape=(X_tr.shape[1], X_tr.shape[2])),
        Dense(32, activation='relu'),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    model.summary()

    history = model.fit(
        X_tr, y_tr,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        shuffle=False,
        verbose=1
    )

    y_pred_scaled = model.predict(X_te, verbose=0)
    y_pred = y_scaler.inverse_transform(y_pred_scaled)
    y_true = y_scaler.inverse_transform(y_te)

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    return mae, rmse, y_true, y_pred

# %%
# Number of models in the ensemble
num_models = 10

# Auto-generate different random seeds each time you run this cell
seeds = np.random.randint(1, 100000, num_models)
print("Using seeds:", seeds)

ensemble_preds = []
metrics = []

for i, s in enumerate(seeds, start=1):
    print(f"\n===== Training ensemble member {i}/{num_models} with seed {s} =====\n")

    mae, rmse, y_true, y_pred = train_lstm_once(
        X_tr, y_tr, X_val, y_val, X_te, y_te, y_scaler,
        epochs=30,
        batch_size=32,
        seed=s        # DIFFERENT SEED EACH RUN
    )

    print(f"\nSeed {s} → MAE = {mae:.2f}, RMSE = {rmse:.2f}\n")

    ensemble_preds.append(y_pred)
    metrics.append((mae, rmse))

ensemble_preds = np.stack(ensemble_preds, axis=0)   # (num_models, n_test, 1)
metrics = np.array(metrics)
# Out:
# Using seeds: [18970  9369 13244 76201 43658  4005 43662 17374 14898 77467]
#
# ===== Training ensemble member 1/10 with seed 18970 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0064 - mae: 0.0654 - val_loss: 0.0135 - val_mae: 0.0955
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0305 - mae: 0.1489 - val_loss: 0.0066 - val_mae: 0.0686
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0128 - mae: 0.0964 - val_loss: 0.0037 - val_mae: 0.0504
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - mae: 0.0282 - val_loss: 0.0048 - val_mae: 0.0556
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - mae: 0.0240 - val_loss: 0.0052 - val_mae: 0.0577
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - mae: 0.0237 - val_loss: 0.0046 - val_mae: 0.0544
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - mae: 0.0237 - val_loss: 0.0037 - val_mae: 0.0490
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - mae: 0.0237 - val_loss: 0.0032 - val_mae: 0.0452
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.0707e-04 - mae: 0.0213 - val_loss: 0.0027 - val_mae: 0.0421
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.2849e-04 - mae: 0.0213 - val_loss: 0.0024 - val_mae: 0.0396
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.6953e-04 - mae: 0.0211 - val_loss: 0.0021 - val_mae: 0.0367
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.2817e-04 - mae: 0.0215 - val_loss: 0.0019 - val_mae: 0.0350
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.5237e-04 - mae: 0.0206 - val_loss: 0.0017 - val_mae: 0.0326
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1301e-04 - mae: 0.0212 - val_loss: 0.0016 - val_mae: 0.0312
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.5644e-04 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0297
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2759e-04 - mae: 0.0214 - val_loss: 0.0014 - val_mae: 0.0288
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8602e-04 - mae: 0.0213 - val_loss: 0.0013 - val_mae: 0.0278
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6990e-04 - mae: 0.0222 - val_loss: 0.0013 - val_mae: 0.0273
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3184e-04 - mae: 0.0219 - val_loss: 0.0012 - val_mae: 0.0268
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0012 - val_mae: 0.0267
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0012 - val_mae: 0.0267
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 0.0013 - val_mae: 0.0274
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - mae: 0.0253 - val_loss: 0.0013 - val_mae: 0.0279
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - mae: 0.0253 - val_loss: 0.0015 - val_mae: 0.0313
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - mae: 0.0240 - val_loss: 0.0019 - val_mae: 0.0362
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.8090e-04 - mae: 0.0211 - val_loss: 0.0023 - val_mae: 0.0416
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.8033e-04 - mae: 0.0182 - val_loss: 0.0020 - val_mae: 0.0388
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 5.0848e-04 - mae: 0.0154 - val_loss: 0.0015 - val_mae: 0.0323
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8627e-04 - mae: 0.0138 - val_loss: 0.0011 - val_mae: 0.0261
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.3369e-04 - mae: 0.0160 - val_loss: 0.0010 - val_mae: 0.0244
#
# Seed 18970 → MAE = 82.34, RMSE = 111.72
#
#
# ===== Training ensemble member 2/10 with seed 9369 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0055 - mae: 0.0610 - val_loss: 0.0104 - val_mae: 0.0834
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0092 - mae: 0.0825 - val_loss: 0.0058 - val_mae: 0.0623
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0119 - mae: 0.0930 - val_loss: 0.0037 - val_mae: 0.0507
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0076 - mae: 0.0729 - val_loss: 0.0036 - val_mae: 0.0509
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0038 - mae: 0.0508 - val_loss: 0.0022 - val_mae: 0.0386
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0219e-04 - mae: 0.0214 - val_loss: 0.0031 - val_mae: 0.0453
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2232e-04 - mae: 0.0163 - val_loss: 0.0033 - val_mae: 0.0471
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.8639e-04 - mae: 0.0198 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.9207e-04 - mae: 0.0201 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 7.4847e-04 - mae: 0.0213 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.2947e-04 - mae: 0.0188 - val_loss: 0.0015 - val_mae: 0.0311
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2741e-04 - mae: 0.0168 - val_loss: 0.0014 - val_mae: 0.0304
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0853e-04 - mae: 0.0164 - val_loss: 0.0015 - val_mae: 0.0308
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.9164e-04 - mae: 0.0160 - val_loss: 0.0014 - val_mae: 0.0308
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7759e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0271
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7384e-04 - mae: 0.0157 - val_loss: 0.0012 - val_mae: 0.0272
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6629e-04 - mae: 0.0157 - val_loss: 0.0012 - val_mae: 0.0277
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4916e-04 - mae: 0.0153 - val_loss: 0.0012 - val_mae: 0.0275
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2770e-04 - mae: 0.0149 - val_loss: 9.8934e-04 - val_mae: 0.0251
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1036e-04 - mae: 0.0144 - val_loss: 9.5943e-04 - val_mae: 0.0246
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4173e-04 - mae: 0.0152 - val_loss: 0.0010 - val_mae: 0.0253
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9382e-04 - mae: 0.0142 - val_loss: 0.0010 - val_mae: 0.0257
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1313e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0257
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9681e-04 - mae: 0.0144 - val_loss: 8.8574e-04 - val_mae: 0.0237
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.1533e-04 - mae: 0.0148 - val_loss: 8.0878e-04 - val_mae: 0.0225
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1216e-04 - mae: 0.0147 - val_loss: 8.1394e-04 - val_mae: 0.0226
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2860e-04 - mae: 0.0152 - val_loss: 8.0882e-04 - val_mae: 0.0226
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.1052e-04 - mae: 0.0149 - val_loss: 7.5488e-04 - val_mae: 0.0216
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1288e-04 - mae: 0.0148 - val_loss: 7.5853e-04 - val_mae: 0.0218
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9346e-04 - mae: 0.0145 - val_loss: 7.2873e-04 - val_mae: 0.0212
#
# Seed 9369 → MAE = 102.37, RMSE = 132.16
#
#
# ===== Training ensemble member 3/10 with seed 13244 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0056 - mae: 0.0614 - val_loss: 0.0086 - val_mae: 0.0755
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0163 - mae: 0.1095 - val_loss: 0.0119 - val_mae: 0.0880
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0160 - mae: 0.1076 - val_loss: 0.0055 - val_mae: 0.0626
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0124 - mae: 0.0940 - val_loss: 0.0021 - val_mae: 0.0380
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - mae: 0.0297 - val_loss: 0.0033 - val_mae: 0.0470
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - mae: 0.0327 - val_loss: 0.0032 - val_mae: 0.0461
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - mae: 0.0274 - val_loss: 0.0030 - val_mae: 0.0446
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8754e-04 - mae: 0.0197 - val_loss: 0.0026 - val_mae: 0.0412
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 6.9998e-04 - mae: 0.0193 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.9000e-04 - mae: 0.0196 - val_loss: 0.0018 - val_mae: 0.0338
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.5296e-04 - mae: 0.0171 - val_loss: 0.0016 - val_mae: 0.0323
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2596e-04 - mae: 0.0160 - val_loss: 0.0016 - val_mae: 0.0318
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.9696e-04 - mae: 0.0156 - val_loss: 0.0015 - val_mae: 0.0310
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6737e-04 - mae: 0.0150 - val_loss: 0.0014 - val_mae: 0.0302
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5625e-04 - mae: 0.0148 - val_loss: 0.0014 - val_mae: 0.0300
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.3033e-04 - mae: 0.0144 - val_loss: 0.0013 - val_mae: 0.0291
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2898e-04 - mae: 0.0143 - val_loss: 0.0013 - val_mae: 0.0293
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0443e-04 - mae: 0.0140 - val_loss: 0.0012 - val_mae: 0.0283
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0070e-04 - mae: 0.0138 - val_loss: 0.0012 - val_mae: 0.0282
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8428e-04 - mae: 0.0136 - val_loss: 0.0011 - val_mae: 0.0273
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8383e-04 - mae: 0.0136 - val_loss: 0.0011 - val_mae: 0.0272
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7122e-04 - mae: 0.0134 - val_loss: 0.0011 - val_mae: 0.0263
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7249e-04 - mae: 0.0134 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6905e-04 - mae: 0.0134 - val_loss: 9.9220e-04 - val_mae: 0.0254
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6880e-04 - mae: 0.0135 - val_loss: 9.5517e-04 - val_mae: 0.0249
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6552e-04 - mae: 0.0135 - val_loss: 9.2495e-04 - val_mae: 0.0244
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7668e-04 - mae: 0.0138 - val_loss: 9.3203e-04 - val_mae: 0.0246
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4815e-04 - mae: 0.0132 - val_loss: 8.6678e-04 - val_mae: 0.0236
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7862e-04 - mae: 0.0140 - val_loss: 8.9780e-04 - val_mae: 0.0241
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4352e-04 - mae: 0.0135 - val_loss: 8.1303e-04 - val_mae: 0.0228
#
# Seed 13244 → MAE = 157.16, RMSE = 194.52
#
#
# ===== Training ensemble member 4/10 with seed 76201 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0060 - mae: 0.0620 - val_loss: 0.0091 - val_mae: 0.0777
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0173 - mae: 0.1118 - val_loss: 0.0092 - val_mae: 0.0771
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0086 - mae: 0.0784 - val_loss: 0.0047 - val_mae: 0.0562
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0036 - mae: 0.0486 - val_loss: 0.0044 - val_mae: 0.0538
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0284 - val_loss: 0.0069 - val_mae: 0.0663
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.6469e-04 - mae: 0.0241 - val_loss: 0.0064 - val_mae: 0.0638
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.8290e-04 - mae: 0.0209 - val_loss: 0.0053 - val_mae: 0.0583
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8630e-04 - mae: 0.0212 - val_loss: 0.0044 - val_mae: 0.0530
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4606e-04 - mae: 0.0204 - val_loss: 0.0038 - val_mae: 0.0492
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2660e-04 - mae: 0.0202 - val_loss: 0.0033 - val_mae: 0.0460
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3958e-04 - mae: 0.0186 - val_loss: 0.0032 - val_mae: 0.0453
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4845e-04 - mae: 0.0185 - val_loss: 0.0028 - val_mae: 0.0422
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9456e-04 - mae: 0.0174 - val_loss: 0.0025 - val_mae: 0.0404
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5422e-04 - mae: 0.0165 - val_loss: 0.0024 - val_mae: 0.0391
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3269e-04 - mae: 0.0160 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2427e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0365
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2692e-04 - mae: 0.0162 - val_loss: 0.0019 - val_mae: 0.0352
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2368e-04 - mae: 0.0163 - val_loss: 0.0018 - val_mae: 0.0339
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2727e-04 - mae: 0.0165 - val_loss: 0.0017 - val_mae: 0.0327
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.1794e-04 - mae: 0.0164 - val_loss: 0.0015 - val_mae: 0.0315
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0099e-04 - mae: 0.0161 - val_loss: 0.0015 - val_mae: 0.0308
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7624e-04 - mae: 0.0156 - val_loss: 0.0014 - val_mae: 0.0303
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.5010e-04 - mae: 0.0150 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.5442e-04 - mae: 0.0150 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4649e-04 - mae: 0.0150 - val_loss: 0.0013 - val_mae: 0.0286
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6017e-04 - mae: 0.0156 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5004e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0270
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5854e-04 - mae: 0.0156 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2586e-04 - mae: 0.0150 - val_loss: 0.0010 - val_mae: 0.0259
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2035e-04 - mae: 0.0147 - val_loss: 9.9277e-04 - val_mae: 0.0256
#
# Seed 76201 → MAE = 190.59, RMSE = 229.84
#
#
# ===== Training ensemble member 5/10 with seed 43658 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0087 - mae: 0.0745 - val_loss: 0.0129 - val_mae: 0.0960
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0338 - mae: 0.1544 - val_loss: 0.0073 - val_mae: 0.0728
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0260 - mae: 0.1375 - val_loss: 0.0046 - val_mae: 0.0576
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0086 - mae: 0.0774 - val_loss: 0.0029 - val_mae: 0.0446
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0040 - mae: 0.0513 - val_loss: 0.0041 - val_mae: 0.0512
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0039 - val_mae: 0.0512
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0042 - val_mae: 0.0542
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0038 - val_mae: 0.0516
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.4229e-04 - mae: 0.0215 - val_loss: 0.0036 - val_mae: 0.0508
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8920e-04 - mae: 0.0210 - val_loss: 0.0033 - val_mae: 0.0479
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.4534e-04 - mae: 0.0205 - val_loss: 0.0030 - val_mae: 0.0460
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9425e-04 - mae: 0.0198 - val_loss: 0.0027 - val_mae: 0.0438
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4246e-04 - mae: 0.0190 - val_loss: 0.0024 - val_mae: 0.0412
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.9734e-04 - mae: 0.0184 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5782e-04 - mae: 0.0179 - val_loss: 0.0019 - val_mae: 0.0357
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2992e-04 - mae: 0.0176 - val_loss: 0.0017 - val_mae: 0.0333
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9540e-04 - mae: 0.0170 - val_loss: 0.0015 - val_mae: 0.0310
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8325e-04 - mae: 0.0170 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.4989e-04 - mae: 0.0163 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6565e-04 - mae: 0.0171 - val_loss: 0.0011 - val_mae: 0.0265
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.3054e-04 - mae: 0.0162 - val_loss: 0.0010 - val_mae: 0.0257
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.2789e-04 - mae: 0.0163 - val_loss: 0.0010 - val_mae: 0.0252
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0746e-04 - mae: 0.0159 - val_loss: 9.9576e-04 - val_mae: 0.0248
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0407e-04 - mae: 0.0160 - val_loss: 0.0010 - val_mae: 0.0247
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.8890e-04 - mae: 0.0157 - val_loss: 0.0010 - val_mae: 0.0248
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.9369e-04 - mae: 0.0160 - val_loss: 0.0011 - val_mae: 0.0249
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6655e-04 - mae: 0.0153 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7204e-04 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0256
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4522e-04 - mae: 0.0151 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4610e-04 - mae: 0.0153 - val_loss: 0.0012 - val_mae: 0.0266
#
# Seed 43658 → MAE = 67.52, RMSE = 87.89
#
#
# ===== Training ensemble member 6/10 with seed 4005 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0072 - mae: 0.0685 - val_loss: 0.0064 - val_mae: 0.0665
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0178 - mae: 0.1143 - val_loss: 0.0048 - val_mae: 0.0593
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0098 - mae: 0.0825 - val_loss: 0.0038 - val_mae: 0.0519
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0025 - mae: 0.0400 - val_loss: 0.0029 - val_mae: 0.0433
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.9418e-04 - mae: 0.0227 - val_loss: 0.0041 - val_mae: 0.0512
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5334e-04 - mae: 0.0188 - val_loss: 0.0043 - val_mae: 0.0530
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.7417e-04 - mae: 0.0210 - val_loss: 0.0035 - val_mae: 0.0478
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.1070e-04 - mae: 0.0218 - val_loss: 0.0029 - val_mae: 0.0437
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1362e-04 - mae: 0.0200 - val_loss: 0.0025 - val_mae: 0.0407
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.4507e-04 - mae: 0.0186 - val_loss: 0.0022 - val_mae: 0.0381
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.0030e-04 - mae: 0.0175 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6129e-04 - mae: 0.0169 - val_loss: 0.0018 - val_mae: 0.0344
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4601e-04 - mae: 0.0166 - val_loss: 0.0017 - val_mae: 0.0331
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1245e-04 - mae: 0.0159 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.0122e-04 - mae: 0.0157 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8345e-04 - mae: 0.0154 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7783e-04 - mae: 0.0154 - val_loss: 0.0013 - val_mae: 0.0290
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6434e-04 - mae: 0.0151 - val_loss: 0.0012 - val_mae: 0.0281
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6079e-04 - mae: 0.0152 - val_loss: 0.0012 - val_mae: 0.0274
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4505e-04 - mae: 0.0148 - val_loss: 0.0011 - val_mae: 0.0267
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4445e-04 - mae: 0.0149 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.3176e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0255
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2956e-04 - mae: 0.0147 - val_loss: 9.7146e-04 - val_mae: 0.0249
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1333e-04 - mae: 0.0143 - val_loss: 9.4318e-04 - val_mae: 0.0245
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0864e-04 - mae: 0.0142 - val_loss: 9.1493e-04 - val_mae: 0.0241
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9706e-04 - mae: 0.0140 - val_loss: 8.8532e-04 - val_mae: 0.0237
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9674e-04 - mae: 0.0140 - val_loss: 8.6180e-04 - val_mae: 0.0234
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.8408e-04 - mae: 0.0137 - val_loss: 8.3983e-04 - val_mae: 0.0231
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9076e-04 - mae: 0.0140 - val_loss: 8.2597e-04 - val_mae: 0.0228
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7768e-04 - mae: 0.0138 - val_loss: 8.0607e-04 - val_mae: 0.0225
#
# Seed 4005 → MAE = 121.15, RMSE = 155.64
#
#
# ===== Training ensemble member 7/10 with seed 43662 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0070 - mae: 0.0700 - val_loss: 0.0074 - val_mae: 0.0712
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0226 - mae: 0.1256 - val_loss: 0.0062 - val_mae: 0.0676
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0131 - mae: 0.0965 - val_loss: 0.0037 - val_mae: 0.0514
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0024 - mae: 0.0392 - val_loss: 0.0045 - val_mae: 0.0543
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0021 - mae: 0.0383 - val_loss: 0.0045 - val_mae: 0.0548
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010 - mae: 0.0248 - val_loss: 0.0037 - val_mae: 0.0504
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - mae: 0.0242 - val_loss: 0.0026 - val_mae: 0.0420
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7063e-04 - mae: 0.0230 - val_loss: 0.0017 - val_mae: 0.0334
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.0762e-04 - mae: 0.0220 - val_loss: 0.0015 - val_mae: 0.0307
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7257e-04 - mae: 0.0214 - val_loss: 0.0013 - val_mae: 0.0288
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.3590e-04 - mae: 0.0209 - val_loss: 0.0012 - val_mae: 0.0274
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2083e-04 - mae: 0.0206 - val_loss: 0.0011 - val_mae: 0.0265
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9730e-04 - mae: 0.0203 - val_loss: 0.0011 - val_mae: 0.0258
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9069e-04 - mae: 0.0202 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.6791e-04 - mae: 0.0199 - val_loss: 0.0010 - val_mae: 0.0247
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6335e-04 - mae: 0.0198 - val_loss: 0.0010 - val_mae: 0.0244
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.5339e-04 - mae: 0.0198 - val_loss: 0.0010 - val_mae: 0.0241
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.3980e-04 - mae: 0.0196 - val_loss: 0.0010 - val_mae: 0.0240
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3087e-04 - mae: 0.0196 - val_loss: 0.0010 - val_mae: 0.0238
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2838e-04 - mae: 0.0197 - val_loss: 0.0010 - val_mae: 0.0237
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0977e-04 - mae: 0.0194 - val_loss: 0.0010 - val_mae: 0.0236
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0203e-04 - mae: 0.0193 - val_loss: 0.0010 - val_mae: 0.0236
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.8080e-04 - mae: 0.0190 - val_loss: 0.0010 - val_mae: 0.0235
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6772e-04 - mae: 0.0189 - val_loss: 0.0010 - val_mae: 0.0235
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3100e-04 - mae: 0.0182 - val_loss: 9.8970e-04 - val_mae: 0.0234
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0831e-04 - mae: 0.0179 - val_loss: 9.8479e-04 - val_mae: 0.0234
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6777e-04 - mae: 0.0172 - val_loss: 9.8004e-04 - val_mae: 0.0234
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2460e-04 - mae: 0.0164 - val_loss: 9.6649e-04 - val_mae: 0.0233
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8583e-04 - mae: 0.0157 - val_loss: 9.6828e-04 - val_mae: 0.0232
#
# Seed 43662 → MAE = 58.84, RMSE = 72.73
#
#
# ===== Training ensemble member 8/10 with seed 17374 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0051 - mae: 0.0583 - val_loss: 0.0104 - val_mae: 0.0821
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0121 - mae: 0.0941 - val_loss: 0.0079 - val_mae: 0.0719
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0149 - mae: 0.1041 - val_loss: 0.0039 - val_mae: 0.0512
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0047 - mae: 0.0574 - val_loss: 0.0032 - val_mae: 0.0467
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0015 - mae: 0.0309 - val_loss: 0.0042 - val_mae: 0.0523
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4766e-04 - mae: 0.0189 - val_loss: 0.0045 - val_mae: 0.0542
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.2139e-04 - mae: 0.0214 - val_loss: 0.0035 - val_mae: 0.0483
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1747e-04 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0376
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - mae: 0.0263 - val_loss: 0.0018 - val_mae: 0.0343
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5173e-04 - mae: 0.0228 - val_loss: 0.0018 - val_mae: 0.0346
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.7738e-04 - mae: 0.0193 - val_loss: 0.0017 - val_mae: 0.0335
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9436e-04 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0285
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0452e-04 - mae: 0.0177 - val_loss: 0.0012 - val_mae: 0.0281
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0568e-04 - mae: 0.0183 - val_loss: 0.0013 - val_mae: 0.0286
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5360e-04 - mae: 0.0174 - val_loss: 0.0011 - val_mae: 0.0260
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2290e-04 - mae: 0.0161 - val_loss: 0.0012 - val_mae: 0.0272
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9482e-04 - mae: 0.0160 - val_loss: 0.0011 - val_mae: 0.0256
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8045e-04 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0258
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.5354e-04 - mae: 0.0153 - val_loss: 0.0010 - val_mae: 0.0246
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.5480e-04 - mae: 0.0150 - val_loss: 0.0010 - val_mae: 0.0254
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2228e-04 - mae: 0.0146 - val_loss: 9.6354e-04 - val_mae: 0.0240
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.1427e-04 - mae: 0.0142 - val_loss: 9.5908e-04 - val_mae: 0.0240
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0340e-04 - mae: 0.0140 - val_loss: 9.3128e-04 - val_mae: 0.0235
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.9056e-04 - mae: 0.0138 - val_loss: 9.0319e-04 - val_mae: 0.0231
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7689e-04 - mae: 0.0135 - val_loss: 8.8205e-04 - val_mae: 0.0227
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6979e-04 - mae: 0.0133 - val_loss: 8.6459e-04 - val_mae: 0.0225
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6043e-04 - mae: 0.0132 - val_loss: 8.4473e-04 - val_mae: 0.0222
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4986e-04 - mae: 0.0129 - val_loss: 8.2651e-04 - val_mae: 0.0220
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4376e-04 - mae: 0.0128 - val_loss: 8.0808e-04 - val_mae: 0.0217
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.3621e-04 - mae: 0.0127 - val_loss: 7.9286e-04 - val_mae: 0.0215
#
# Seed 17374 → MAE = 84.00, RMSE = 113.29
#
#
# ===== Training ensemble member 9/10 with seed 14898 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0063 - mae: 0.0640 - val_loss: 0.0065 - val_mae: 0.0659
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0252 - mae: 0.1357 - val_loss: 0.0046 - val_mae: 0.0584
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0101 - mae: 0.0868 - val_loss: 0.0039 - val_mae: 0.0532
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - mae: 0.0513 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6586e-04 - mae: 0.0254 - val_loss: 0.0032 - val_mae: 0.0462
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.2466e-04 - mae: 0.0211 - val_loss: 0.0024 - val_mae: 0.0406
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.3943e-04 - mae: 0.0234 - val_loss: 0.0020 - val_mae: 0.0374
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.4803e-04 - mae: 0.0219 - val_loss: 0.0018 - val_mae: 0.0345
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.3197e-04 - mae: 0.0215 - val_loss: 0.0015 - val_mae: 0.0318
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.1081e-04 - mae: 0.0212 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8213e-04 - mae: 0.0207 - val_loss: 0.0013 - val_mae: 0.0284
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7153e-04 - mae: 0.0205 - val_loss: 0.0012 - val_mae: 0.0274
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4446e-04 - mae: 0.0201 - val_loss: 0.0011 - val_mae: 0.0268
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.3521e-04 - mae: 0.0199 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0644e-04 - mae: 0.0194 - val_loss: 0.0010 - val_mae: 0.0247
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.9307e-04 - mae: 0.0192 - val_loss: 9.8848e-04 - val_mae: 0.0241
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.8541e-04 - mae: 0.0192 - val_loss: 9.7159e-04 - val_mae: 0.0236
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7925e-04 - mae: 0.0191 - val_loss: 9.7036e-04 - val_mae: 0.0233
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6404e-04 - mae: 0.0189 - val_loss: 9.6798e-04 - val_mae: 0.0231
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5897e-04 - mae: 0.0188 - val_loss: 9.7735e-04 - val_mae: 0.0231
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4603e-04 - mae: 0.0186 - val_loss: 9.7822e-04 - val_mae: 0.0230
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3882e-04 - mae: 0.0185 - val_loss: 9.8664e-04 - val_mae: 0.0231
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2629e-04 - mae: 0.0183 - val_loss: 9.8409e-04 - val_mae: 0.0231
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.1977e-04 - mae: 0.0182 - val_loss: 9.9713e-04 - val_mae: 0.0232
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0182e-04 - mae: 0.0180 - val_loss: 9.9600e-04 - val_mae: 0.0233
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8557e-04 - mae: 0.0177 - val_loss: 9.9640e-04 - val_mae: 0.0233
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6762e-04 - mae: 0.0174 - val_loss: 9.9557e-04 - val_mae: 0.0233
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4700e-04 - mae: 0.0171 - val_loss: 9.9177e-04 - val_mae: 0.0233
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2448e-04 - mae: 0.0167 - val_loss: 9.8941e-04 - val_mae: 0.0233
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0077e-04 - mae: 0.0164 - val_loss: 9.9107e-04 - val_mae: 0.0233
#
# Seed 14898 → MAE = 59.55, RMSE = 72.70
#
#
# ===== Training ensemble member 10/10 with seed 77467 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0078 - mae: 0.0702 - val_loss: 0.0108 - val_mae: 0.0839
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0230 - mae: 0.1259 - val_loss: 0.0047 - val_mae: 0.0551
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0066 - mae: 0.0678 - val_loss: 0.0035 - val_mae: 0.0472
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - mae: 0.0281 - val_loss: 0.0038 - val_mae: 0.0498
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7231e-04 - mae: 0.0196 - val_loss: 0.0032 - val_mae: 0.0453
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2763e-04 - mae: 0.0184 - val_loss: 0.0020 - val_mae: 0.0358
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6203e-04 - mae: 0.0237 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0013 - val_mae: 0.0285
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - mae: 0.0266 - val_loss: 0.0012 - val_mae: 0.0275
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.3940e-04 - mae: 0.0218 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.1256e-04 - mae: 0.0179 - val_loss: 0.0012 - val_mae: 0.0267
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5221e-04 - mae: 0.0185 - val_loss: 0.0011 - val_mae: 0.0264
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.9456e-04 - mae: 0.0172 - val_loss: 0.0011 - val_mae: 0.0259
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9905e-04 - mae: 0.0177 - val_loss: 0.0012 - val_mae: 0.0266
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.0625e-04 - mae: 0.0178 - val_loss: 0.0010 - val_mae: 0.0245
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6167e-04 - mae: 0.0171 - val_loss: 0.0010 - val_mae: 0.0243
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.4391e-04 - mae: 0.0166 - val_loss: 9.9851e-04 - val_mae: 0.0240
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.3403e-04 - mae: 0.0163 - val_loss: 9.9145e-04 - val_mae: 0.0238
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2443e-04 - mae: 0.0161 - val_loss: 9.9151e-04 - val_mae: 0.0236
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2903e-04 - mae: 0.0165 - val_loss: 9.9371e-04 - val_mae: 0.0235
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0643e-04 - mae: 0.0160 - val_loss: 9.9027e-04 - val_mae: 0.0234
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.1181e-04 - mae: 0.0163 - val_loss: 9.9128e-04 - val_mae: 0.0234
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8866e-04 - mae: 0.0156 - val_loss: 9.9689e-04 - val_mae: 0.0234
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0272e-04 - mae: 0.0162 - val_loss: 0.0010 - val_mae: 0.0234
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8217e-04 - mae: 0.0157 - val_loss: 9.9997e-04 - val_mae: 0.0234
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0367e-04 - mae: 0.0164 - val_loss: 0.0010 - val_mae: 0.0236
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6799e-04 - mae: 0.0155 - val_loss: 0.0010 - val_mae: 0.0235
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7803e-04 - mae: 0.0159 - val_loss: 0.0010 - val_mae: 0.0237
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6817e-04 - mae: 0.0157 - val_loss: 0.0010 - val_mae: 0.0240
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7802e-04 - mae: 0.0162 - val_loss: 0.0010 - val_mae: 0.0237
#
# Seed 77467 → MAE = 60.21, RMSE = 78.54

# %%
import numpy as np
import pandas as pd
import os, random

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout

import matplotlib.pyplot as plt

# %%
# Make sure Gold_df has 'Close' , 'Vol','log_egarch_vol_ewm'
data = Gold_df[['Close', 'Vol','log_egarch_vol_ewm']].dropna().values  # shape (N, 3)

window_size = 14   # you can tune this
n = len(data)
print("Total rows:", n)

# Time-based 80/10/10 split
train_end = int(n * 0.8)
val_end   = int(n * 0.9)

train_raw = data[:train_end]
val_raw   = data[train_end - window_size : val_end]   # include overlap
test_raw  = data[val_end - window_size :]             # include overlap

print("Train raw:", train_raw.shape)
print("Val raw  :", val_raw.shape)
print("Test raw :", test_raw.shape)
# Out:
# Total rows: 2039
# Train raw: (1631, 3)
# Val raw  : (218, 3)
# Test raw : (218, 3)

# %%
def create_sequences(X_data, y_data, window_size=14):
    """
    X_data: (N, n_features)
    y_data: (N, 1)
    Returns:
      X: (num_samples, window_size, n_features)
      y: (num_samples, 1)
    """
    X, y = [], []
    for i in range(window_size, len(X_data)):
        X.append(X_data[i-window_size:i])
        y.append(y_data[i])
    return np.array(X), np.array(y)

# %%
# Feature scaler (Close + Vol)
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(train_raw)
X_val_scaled   = X_scaler.transform(val_raw)
X_test_scaled  = X_scaler.transform(test_raw)

# Target scaler (Close only)
y_scaler = MinMaxScaler()

close_train = train_raw[:, 0].reshape(-1, 1)
close_val   = val_raw[:, 0].reshape(-1, 1)
close_test  = test_raw[:, 0].reshape(-1, 1)

y_train_scaled_full = y_scaler.fit_transform(close_train)
y_val_scaled_full   = y_scaler.transform(close_val)
y_test_scaled_full  = y_scaler.transform(close_test)

# %%
X_tr, y_tr = create_sequences(X_train_scaled, y_train_scaled_full, window_size)
X_val, y_val = create_sequences(X_val_scaled, y_val_scaled_full, window_size)
X_te, y_te = create_sequences(X_test_scaled, y_test_scaled_full, window_size)

print("Train seq:", X_tr.shape, y_tr.shape)
print("Val seq  :", X_val.shape, y_val.shape)
print("Test seq :", X_te.shape, y_te.shape)
# Out:
# Train seq: (1617, 14, 3) (1617, 1)
# Val seq  : (204, 14, 3) (204, 1)
# Test seq : (204, 14, 3) (204, 1)

# %%
# Feature scaler (Close + Vol,EGARCH)
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(train_raw)
X_val_scaled   = X_scaler.transform(val_raw)
X_test_scaled  = X_scaler.transform(test_raw)

# Target scaler (Close only)
y_scaler = MinMaxScaler()

close_train = train_raw[:, 0].reshape(-1, 1)
close_val   = val_raw[:, 0].reshape(-1, 1)
close_test  = test_raw[:, 0].reshape(-1, 1)

y_train_scaled_full = y_scaler.fit_transform(close_train)
y_val_scaled_full   = y_scaler.transform(close_val)
y_test_scaled_full  = y_scaler.transform(close_test)

# %%
def train_lstm_once(
    X_tr, y_tr, X_val, y_val, X_te, y_te, y_scaler,
    epochs=30, batch_size=32, seed=None
):
    tf.keras.backend.clear_session()

    if seed is not None:
        seed = int(seed)   # FIX

        np.random.seed(seed)
        random.seed(seed)
        tf.random.set_seed(seed)
        os.environ["PYTHONHASHSEED"] = str(seed)
        os.environ["TF_DETERMINISTIC_OPS"] = "1"

    # ==== CHANGED ONLY THIS PART (LSTM → Bidirectional LSTM) ====
    model = Sequential([
        Bidirectional(LSTM(64, return_sequences=False),
                      input_shape=(X_tr.shape[1], X_tr.shape[2])),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    # =============================================================

    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    model.summary()

    history = model.fit(
        X_tr, y_tr,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        shuffle=False,
        verbose=1
    )

    y_pred_scaled = model.predict(X_te, verbose=0)
    y_pred = y_scaler.inverse_transform(y_pred_scaled)
    y_true = y_scaler.inverse_transform(y_te)

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    return mae, rmse, y_true, y_pred

# %%
# Number of models in the ensemble
num_models = 10

# Auto-generate different random seeds each time you run this cell
seeds = np.random.randint(1, 100000, num_models)
print("Using seeds:", seeds)

ensemble_preds = []
metrics = []

for i, s in enumerate(seeds, start=1):
    print(f"\n===== Training ensemble member {i}/{num_models} with seed {s} =====\n")

    mae, rmse, y_true, y_pred = train_lstm_once(
        X_tr, y_tr, X_val, y_val, X_te, y_te, y_scaler,
        epochs=30,
        batch_size=32,
        seed=s        # DIFFERENT SEED EACH RUN
    )

    print(f"\nSeed {s} → MAE = {mae:.2f}, RMSE = {rmse:.2f}\n")

    ensemble_preds.append(y_pred)
    metrics.append((mae, rmse))

ensemble_preds = np.stack(ensemble_preds, axis=0)   # (num_models, n_test, 1)
metrics = np.array(metrics)
# Out:
# Using seeds: [99422 50101 11099 53206 26928 96705 61019 23395 83472 67089]
#
# ===== Training ensemble member 1/10 with seed 99422 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0072 - mae: 0.0695 - val_loss: 0.0086 - val_mae: 0.0745
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0101 - mae: 0.0835 - val_loss: 0.0059 - val_mae: 0.0623
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0094 - mae: 0.0797 - val_loss: 0.0040 - val_mae: 0.0518
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0040 - mae: 0.0505 - val_loss: 0.0031 - val_mae: 0.0453
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.4472e-04 - mae: 0.0220 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - mae: 0.0304 - val_loss: 0.0021 - val_mae: 0.0365
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0032 - val_mae: 0.0451
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - mae: 0.0316 - val_loss: 0.0046 - val_mae: 0.0557
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0014 - val_mae: 0.0295
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0016 - mae: 0.0299 - val_loss: 0.0015 - val_mae: 0.0301
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0011 - mae: 0.0257 - val_loss: 0.0016 - val_mae: 0.0304
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 0.0016 - val_mae: 0.0298
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - mae: 0.0253 - val_loss: 0.0015 - val_mae: 0.0293
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0015 - val_mae: 0.0292
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 0.0016 - val_mae: 0.0315
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0253 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 0.0027 - val_mae: 0.0453
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.7499e-04 - mae: 0.0220 - val_loss: 0.0029 - val_mae: 0.0474
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.5682e-04 - mae: 0.0195 - val_loss: 0.0023 - val_mae: 0.0412
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5297e-04 - mae: 0.0165 - val_loss: 0.0017 - val_mae: 0.0334
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7662e-04 - mae: 0.0153 - val_loss: 0.0014 - val_mae: 0.0302
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9556e-04 - mae: 0.0164 - val_loss: 0.0012 - val_mae: 0.0285
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.2983e-04 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0276
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.6441e-04 - mae: 0.0151 - val_loss: 0.0011 - val_mae: 0.0260
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 4.6318e-04 - mae: 0.0148 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1587e-04 - mae: 0.0163 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9762e-04 - mae: 0.0160 - val_loss: 0.0011 - val_mae: 0.0245
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8911e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0245
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1262e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0247
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2593e-04 - mae: 0.0164 - val_loss: 0.0011 - val_mae: 0.0249
#
# Seed 99422 → MAE = 92.12, RMSE = 110.95
#
#
# ===== Training ensemble member 2/10 with seed 50101 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0095 - mae: 0.0761 - val_loss: 0.0089 - val_mae: 0.0781
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0217 - mae: 0.1228 - val_loss: 0.0076 - val_mae: 0.0707
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0108 - mae: 0.0865 - val_loss: 0.0042 - val_mae: 0.0547
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0049 - mae: 0.0566 - val_loss: 0.0032 - val_mae: 0.0465
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.9759e-04 - mae: 0.0238 - val_loss: 0.0036 - val_mae: 0.0480
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.9379e-04 - mae: 0.0202 - val_loss: 0.0029 - val_mae: 0.0430
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mae: 0.0276 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - mae: 0.0314 - val_loss: 0.0022 - val_mae: 0.0378
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0266 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 0.0018 - val_mae: 0.0343
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0017 - val_mae: 0.0331
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0016 - val_mae: 0.0322
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0016 - val_mae: 0.0308
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0015 - val_mae: 0.0301
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0015 - val_mae: 0.0297
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0241 - val_loss: 0.0015 - val_mae: 0.0291
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mae: 0.0247 - val_loss: 0.0014 - val_mae: 0.0289
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0242 - val_loss: 0.0015 - val_mae: 0.0299
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 0.0017 - val_mae: 0.0328
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0021 - val_mae: 0.0379
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0027 - val_mae: 0.0447
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.8821e-04 - mae: 0.0199 - val_loss: 0.0028 - val_mae: 0.0466
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.5505e-04 - mae: 0.0170 - val_loss: 0.0022 - val_mae: 0.0393
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.0082e-04 - mae: 0.0151 - val_loss: 0.0015 - val_mae: 0.0318
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7531e-04 - mae: 0.0162 - val_loss: 0.0013 - val_mae: 0.0288
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.7143e-04 - mae: 0.0244 - val_loss: 0.0014 - val_mae: 0.0301
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3027e-04 - mae: 0.0230 - val_loss: 0.0012 - val_mae: 0.0284
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8638e-04 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0267
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3859e-04 - mae: 0.0149 - val_loss: 0.0011 - val_mae: 0.0255
#
# Seed 50101 → MAE = 56.22, RMSE = 69.80
#
#
# ===== Training ensemble member 3/10 with seed 11099 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0080 - mae: 0.0732 - val_loss: 0.0050 - val_mae: 0.0583
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0134 - mae: 0.0967 - val_loss: 0.0049 - val_mae: 0.0572
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0069 - mae: 0.0670 - val_loss: 0.0030 - val_mae: 0.0446
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6183e-04 - mae: 0.0244 - val_loss: 0.0020 - val_mae: 0.0372
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mae: 0.0287 - val_loss: 0.0021 - val_mae: 0.0364
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0018 - val_mae: 0.0347
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0018 - val_mae: 0.0349
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mae: 0.0276 - val_loss: 0.0017 - val_mae: 0.0324
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012 - mae: 0.0263 - val_loss: 0.0017 - val_mae: 0.0322
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 0.0017 - val_mae: 0.0317
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0012 - mae: 0.0255 - val_loss: 0.0016 - val_mae: 0.0311
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mae: 0.0271 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0015 - val_mae: 0.0303
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0016 - val_mae: 0.0322
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mae: 0.0264 - val_loss: 0.0019 - val_mae: 0.0351
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0242 - val_loss: 0.0023 - val_mae: 0.0405
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.9999e-04 - mae: 0.0220 - val_loss: 0.0020 - val_mae: 0.0365
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2044e-04 - mae: 0.0199 - val_loss: 0.0021 - val_mae: 0.0378
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.5968e-04 - mae: 0.0177 - val_loss: 0.0018 - val_mae: 0.0347
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3211e-04 - mae: 0.0159 - val_loss: 0.0015 - val_mae: 0.0313
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 5.1393e-04 - mae: 0.0162 - val_loss: 0.0014 - val_mae: 0.0296
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.6566e-04 - mae: 0.0201 - val_loss: 0.0014 - val_mae: 0.0296
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.9908e-04 - mae: 0.0224 - val_loss: 0.0014 - val_mae: 0.0296
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1128e-04 - mae: 0.0165 - val_loss: 0.0013 - val_mae: 0.0273
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6798e-04 - mae: 0.0151 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6272e-04 - mae: 0.0152 - val_loss: 0.0013 - val_mae: 0.0269
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8134e-04 - mae: 0.0157 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8211e-04 - mae: 0.0157 - val_loss: 0.0015 - val_mae: 0.0282
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.8566e-04 - mae: 0.0157 - val_loss: 0.0015 - val_mae: 0.0288
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7820e-04 - mae: 0.0153 - val_loss: 0.0016 - val_mae: 0.0294
#
# Seed 11099 → MAE = 125.14, RMSE = 143.49
#
#
# ===== Training ensemble member 4/10 with seed 53206 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0095 - mae: 0.0762 - val_loss: 0.0069 - val_mae: 0.0683
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0154 - mae: 0.1038 - val_loss: 0.0050 - val_mae: 0.0606
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0088 - mae: 0.0773 - val_loss: 0.0039 - val_mae: 0.0529
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0025 - val_mae: 0.0407
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.8746e-04 - mae: 0.0229 - val_loss: 0.0030 - val_mae: 0.0436
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.3396e-04 - mae: 0.0210 - val_loss: 0.0025 - val_mae: 0.0396
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0020 - val_mae: 0.0359
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.0884e-04 - mae: 0.0224 - val_loss: 0.0017 - val_mae: 0.0338
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3527e-04 - mae: 0.0211 - val_loss: 0.0016 - val_mae: 0.0325
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.2235e-04 - mae: 0.0207 - val_loss: 0.0015 - val_mae: 0.0316
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.6441e-04 - mae: 0.0197 - val_loss: 0.0014 - val_mae: 0.0308
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.6216e-04 - mae: 0.0195 - val_loss: 0.0014 - val_mae: 0.0300
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6260e-04 - mae: 0.0195 - val_loss: 0.0013 - val_mae: 0.0291
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.6252e-04 - mae: 0.0193 - val_loss: 0.0013 - val_mae: 0.0285
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.6015e-04 - mae: 0.0194 - val_loss: 0.0013 - val_mae: 0.0280
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.6368e-04 - mae: 0.0194 - val_loss: 0.0012 - val_mae: 0.0275
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6119e-04 - mae: 0.0193 - val_loss: 0.0012 - val_mae: 0.0271
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 7.8922e-04 - mae: 0.0195 - val_loss: 0.0012 - val_mae: 0.0270
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.9804e-04 - mae: 0.0202 - val_loss: 0.0012 - val_mae: 0.0266
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.9742e-04 - mae: 0.0200 - val_loss: 0.0012 - val_mae: 0.0262
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0868e-04 - mae: 0.0196 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9376e-04 - mae: 0.0215 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.2944e-04 - mae: 0.0207 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.7023e-04 - mae: 0.0208 - val_loss: 0.0011 - val_mae: 0.0249
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.1055e-04 - mae: 0.0217 - val_loss: 0.0011 - val_mae: 0.0248
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.3792e-04 - mae: 0.0233 - val_loss: 0.0011 - val_mae: 0.0247
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2392e-04 - mae: 0.0213 - val_loss: 0.0011 - val_mae: 0.0254
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3575e-04 - mae: 0.0201 - val_loss: 0.0012 - val_mae: 0.0280
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.7123e-04 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0287
#
# Seed 53206 → MAE = 53.60, RMSE = 68.45
#
#
# ===== Training ensemble member 5/10 with seed 26928 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0053 - mae: 0.0601 - val_loss: 0.0100 - val_mae: 0.0802
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0108 - mae: 0.0872 - val_loss: 0.0052 - val_mae: 0.0593
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0060 - mae: 0.0607 - val_loss: 0.0039 - val_mae: 0.0507
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0020 - val_mae: 0.0360
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mae: 0.0281 - val_loss: 0.0019 - val_mae: 0.0350
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0016 - val_mae: 0.0324
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0014 - val_mae: 0.0296
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0018 - mae: 0.0344 - val_loss: 0.0015 - val_mae: 0.0298
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0319
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0253 - val_loss: 0.0015 - val_mae: 0.0293
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0016 - val_mae: 0.0295
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0016 - val_mae: 0.0296
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0015 - val_mae: 0.0290
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0016 - val_mae: 0.0291
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0262 - val_loss: 0.0015 - val_mae: 0.0287
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0253 - val_loss: 0.0014 - val_mae: 0.0273
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0247 - val_loss: 0.0014 - val_mae: 0.0274
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 0.0013 - val_mae: 0.0278
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 0.0014 - val_mae: 0.0286
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.7516e-04 - mae: 0.0227 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.4066e-04 - mae: 0.0208 - val_loss: 0.0015 - val_mae: 0.0316
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.7039e-04 - mae: 0.0181 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5071e-04 - mae: 0.0162 - val_loss: 0.0012 - val_mae: 0.0271
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6065e-04 - mae: 0.0147 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1315e-04 - mae: 0.0139 - val_loss: 0.0011 - val_mae: 0.0244
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9544e-04 - mae: 0.0136 - val_loss: 0.0011 - val_mae: 0.0244
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9333e-04 - mae: 0.0136 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0163e-04 - mae: 0.0137 - val_loss: 0.0012 - val_mae: 0.0249
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1427e-04 - mae: 0.0139 - val_loss: 0.0012 - val_mae: 0.0256
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3537e-04 - mae: 0.0143 - val_loss: 0.0013 - val_mae: 0.0262
#
# Seed 26928 → MAE = 81.49, RMSE = 97.53
#
#
# ===== Training ensemble member 6/10 with seed 96705 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0058 - mae: 0.0623 - val_loss: 0.0090 - val_mae: 0.0762
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0088 - mae: 0.0800 - val_loss: 0.0041 - val_mae: 0.0529
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mae: 0.0630 - val_loss: 0.0031 - val_mae: 0.0456
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014 - mae: 0.0302 - val_loss: 0.0024 - val_mae: 0.0394
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0018 - mae: 0.0305 - val_loss: 0.0023 - val_mae: 0.0391
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - mae: 0.0297 - val_loss: 0.0021 - val_mae: 0.0362
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mae: 0.0304 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017 - mae: 0.0325 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0014 - mae: 0.0295 - val_loss: 0.0014 - val_mae: 0.0294
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.4913e-04 - mae: 0.0229 - val_loss: 0.0015 - val_mae: 0.0298
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.9036e-04 - mae: 0.0222 - val_loss: 0.0014 - val_mae: 0.0293
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - mae: 0.0247 - val_loss: 0.0015 - val_mae: 0.0294
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0259 - val_loss: 0.0014 - val_mae: 0.0286
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 0.0014 - val_mae: 0.0283
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0231 - val_loss: 0.0013 - val_mae: 0.0273
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - mae: 0.0261 - val_loss: 0.0013 - val_mae: 0.0271
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0267 - val_loss: 0.0013 - val_mae: 0.0278
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0019 - val_mae: 0.0364
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0010 - mae: 0.0236 - val_loss: 0.0021 - val_mae: 0.0388
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.4035e-04 - mae: 0.0193 - val_loss: 0.0020 - val_mae: 0.0375
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.4954e-04 - mae: 0.0163 - val_loss: 0.0016 - val_mae: 0.0324
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5758e-04 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0293
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.7128e-04 - mae: 0.0259 - val_loss: 0.0013 - val_mae: 0.0298
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3882e-04 - mae: 0.0178 - val_loss: 0.0011 - val_mae: 0.0261
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2655e-04 - mae: 0.0149 - val_loss: 9.9087e-04 - val_mae: 0.0243
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8072e-04 - mae: 0.0142 - val_loss: 9.9303e-04 - val_mae: 0.0238
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7365e-04 - mae: 0.0133 - val_loss: 0.0010 - val_mae: 0.0237
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9128e-04 - mae: 0.0135 - val_loss: 0.0010 - val_mae: 0.0238
#
# Seed 96705 → MAE = 65.76, RMSE = 80.98
#
#
# ===== Training ensemble member 7/10 with seed 61019 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0090 - mae: 0.0748 - val_loss: 0.0140 - val_mae: 0.0993
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0365 - mae: 0.1604 - val_loss: 0.0071 - val_mae: 0.0718
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0141 - mae: 0.0951 - val_loss: 0.0056 - val_mae: 0.0622
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0077 - mae: 0.0742 - val_loss: 0.0026 - val_mae: 0.0419
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - mae: 0.0337 - val_loss: 0.0033 - val_mae: 0.0455
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0031 - val_mae: 0.0438
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - mae: 0.0325 - val_loss: 0.0024 - val_mae: 0.0386
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0015 - mae: 0.0291 - val_loss: 0.0021 - val_mae: 0.0362
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 0.0021 - val_mae: 0.0363
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - mae: 0.0271 - val_loss: 0.0023 - val_mae: 0.0381
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - mae: 0.0286 - val_loss: 0.0027 - val_mae: 0.0424
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - mae: 0.0277 - val_loss: 0.0041 - val_mae: 0.0549
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mae: 0.0268 - val_loss: 0.0057 - val_mae: 0.0670
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 0.0066 - val_mae: 0.0733
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0831e-04 - mae: 0.0209 - val_loss: 0.0055 - val_mae: 0.0659
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5911e-04 - mae: 0.0176 - val_loss: 0.0038 - val_mae: 0.0525
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5877e-04 - mae: 0.0165 - val_loss: 0.0028 - val_mae: 0.0441
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3413e-04 - mae: 0.0162 - val_loss: 0.0023 - val_mae: 0.0403
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3367e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0384
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.4351e-04 - mae: 0.0159 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.6123e-04 - mae: 0.0161 - val_loss: 0.0018 - val_mae: 0.0351
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8544e-04 - mae: 0.0165 - val_loss: 0.0016 - val_mae: 0.0327
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.0537e-04 - mae: 0.0170 - val_loss: 0.0016 - val_mae: 0.0320
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.6419e-04 - mae: 0.0185 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6791e-04 - mae: 0.0186 - val_loss: 0.0014 - val_mae: 0.0302
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.5353e-04 - mae: 0.0182 - val_loss: 0.0014 - val_mae: 0.0293
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0691e-04 - mae: 0.0172 - val_loss: 0.0013 - val_mae: 0.0287
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.6363e-04 - mae: 0.0163 - val_loss: 0.0012 - val_mae: 0.0277
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3214e-04 - mae: 0.0157 - val_loss: 0.0012 - val_mae: 0.0268
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8991e-04 - mae: 0.0149 - val_loss: 0.0011 - val_mae: 0.0259
#
# Seed 61019 → MAE = 82.20, RMSE = 111.84
#
#
# ===== Training ensemble member 8/10 with seed 23395 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0052 - mae: 0.0597 - val_loss: 0.0132 - val_mae: 0.0932
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0076 - mae: 0.0725 - val_loss: 0.0052 - val_mae: 0.0591
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0084 - mae: 0.0753 - val_loss: 0.0036 - val_mae: 0.0490
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0030 - mae: 0.0437 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0578e-04 - mae: 0.0214 - val_loss: 0.0023 - val_mae: 0.0387
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mae: 0.0299 - val_loss: 0.0023 - val_mae: 0.0384
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - mae: 0.0326 - val_loss: 0.0016 - val_mae: 0.0317
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0016 - mae: 0.0313 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0011 - mae: 0.0261 - val_loss: 0.0015 - val_mae: 0.0301
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.9035e-04 - mae: 0.0222 - val_loss: 0.0015 - val_mae: 0.0302
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.2641e-04 - mae: 0.0211 - val_loss: 0.0016 - val_mae: 0.0302
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.0986e-04 - mae: 0.0220 - val_loss: 0.0015 - val_mae: 0.0293
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010 - mae: 0.0238 - val_loss: 0.0015 - val_mae: 0.0295
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.3636e-04 - mae: 0.0226 - val_loss: 0.0029 - val_mae: 0.0421
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8384e-04 - mae: 0.0209 - val_loss: 0.0014 - val_mae: 0.0284
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.5207e-04 - mae: 0.0195 - val_loss: 0.0015 - val_mae: 0.0282
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6317e-04 - mae: 0.0232 - val_loss: 0.0016 - val_mae: 0.0287
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0010 - mae: 0.0243 - val_loss: 0.0016 - val_mae: 0.0293
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.2593e-04 - mae: 0.0224 - val_loss: 0.0013 - val_mae: 0.0266
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.2961e-04 - mae: 0.0218 - val_loss: 0.0015 - val_mae: 0.0280
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.2844e-04 - mae: 0.0229 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.2635e-04 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0262
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.0661e-04 - mae: 0.0221 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.4340e-04 - mae: 0.0211 - val_loss: 0.0013 - val_mae: 0.0277
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.2925e-04 - mae: 0.0191 - val_loss: 0.0013 - val_mae: 0.0281
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0127e-04 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8156e-04 - mae: 0.0150 - val_loss: 0.0011 - val_mae: 0.0250
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8049e-04 - mae: 0.0135 - val_loss: 0.0010 - val_mae: 0.0237
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9154e-04 - mae: 0.0146 - val_loss: 9.7857e-04 - val_mae: 0.0232
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.0695e-04 - mae: 0.0202 - val_loss: 9.4622e-04 - val_mae: 0.0230
#
# Seed 23395 → MAE = 56.64, RMSE = 74.58
#
#
# ===== Training ensemble member 9/10 with seed 83472 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0069 - mae: 0.0672 - val_loss: 0.0051 - val_mae: 0.0594
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0157 - mae: 0.1074 - val_loss: 0.0046 - val_mae: 0.0575
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0142 - mae: 0.0955 - val_loss: 0.0031 - val_mae: 0.0460
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - mae: 0.0310 - val_loss: 0.0030 - val_mae: 0.0446
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 8.8692e-04 - mae: 0.0239 - val_loss: 0.0041 - val_mae: 0.0515
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0115e-04 - mae: 0.0210 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0273 - val_loss: 0.0018 - val_mae: 0.0353
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - mae: 0.0341 - val_loss: 0.0017 - val_mae: 0.0339
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0018 - val_mae: 0.0347
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0016 - val_mae: 0.0324
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.1178e-04 - mae: 0.0229 - val_loss: 0.0015 - val_mae: 0.0313
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.9730e-04 - mae: 0.0215 - val_loss: 0.0015 - val_mae: 0.0307
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.4066e-04 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.8473e-04 - mae: 0.0216 - val_loss: 0.0014 - val_mae: 0.0292
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.4765e-04 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0289
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.6473e-04 - mae: 0.0212 - val_loss: 0.0013 - val_mae: 0.0285
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.4664e-04 - mae: 0.0206 - val_loss: 0.0013 - val_mae: 0.0282
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.6715e-04 - mae: 0.0209 - val_loss: 0.0013 - val_mae: 0.0279
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.7207e-04 - mae: 0.0213 - val_loss: 0.0013 - val_mae: 0.0276
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.0591e-04 - mae: 0.0214 - val_loss: 0.0013 - val_mae: 0.0274
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.2152e-04 - mae: 0.0220 - val_loss: 0.0013 - val_mae: 0.0271
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5672e-04 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0267
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.5512e-04 - mae: 0.0224 - val_loss: 0.0012 - val_mae: 0.0262
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8313e-04 - mae: 0.0223 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.8669e-04 - mae: 0.0226 - val_loss: 0.0012 - val_mae: 0.0263
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7423e-04 - mae: 0.0223 - val_loss: 0.0013 - val_mae: 0.0278
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.2812e-04 - mae: 0.0217 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 8.1638e-04 - mae: 0.0197 - val_loss: 0.0017 - val_mae: 0.0340
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6807e-04 - mae: 0.0176 - val_loss: 0.0016 - val_mae: 0.0331
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.9844e-04 - mae: 0.0151 - val_loss: 0.0011 - val_mae: 0.0259
#
# Seed 83472 → MAE = 52.79, RMSE = 65.98
#
#
# ===== Training ensemble member 10/10 with seed 67089 =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 0.0047 - mae: 0.0541 - val_loss: 0.0047 - val_mae: 0.0553
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0036 - mae: 0.0491 - val_loss: 0.0018 - val_mae: 0.0354
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - mae: 0.0423 - val_loss: 0.0029 - val_mae: 0.0438
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.8299e-04 - mae: 0.0200 - val_loss: 0.0016 - val_mae: 0.0327
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5998e-04 - mae: 0.0226 - val_loss: 0.0015 - val_mae: 0.0323
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3872e-04 - mae: 0.0220 - val_loss: 0.0019 - val_mae: 0.0348
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mae: 0.0324 - val_loss: 0.0020 - val_mae: 0.0344
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - mae: 0.0320 - val_loss: 0.0024 - val_mae: 0.0383
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0287 - val_loss: 0.0026 - val_mae: 0.0402
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0286 - val_loss: 0.0030 - val_mae: 0.0441
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0277 - val_loss: 0.0023 - val_mae: 0.0377
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0017 - val_mae: 0.0312
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.6713e-04 - mae: 0.0220 - val_loss: 0.0012 - val_mae: 0.0258
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.2715e-04 - mae: 0.0204 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.7350e-04 - mae: 0.0190 - val_loss: 0.0013 - val_mae: 0.0272
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0843e-04 - mae: 0.0192 - val_loss: 0.0014 - val_mae: 0.0272
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.3016e-04 - mae: 0.0176 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1101e-04 - mae: 0.0173 - val_loss: 0.0014 - val_mae: 0.0279
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1583e-04 - mae: 0.0175 - val_loss: 0.0014 - val_mae: 0.0281
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0689e-04 - mae: 0.0184 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2362e-04 - mae: 0.0190 - val_loss: 0.0015 - val_mae: 0.0285
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.9069e-04 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0279
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 5.7924e-04 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0269
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.4709e-04 - mae: 0.0169 - val_loss: 0.0013 - val_mae: 0.0268
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2993e-04 - mae: 0.0171 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2438e-04 - mae: 0.0169 - val_loss: 0.0013 - val_mae: 0.0271
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0547e-04 - mae: 0.0165 - val_loss: 0.0013 - val_mae: 0.0270
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1287e-04 - mae: 0.0162 - val_loss: 0.0013 - val_mae: 0.0274
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1642e-04 - mae: 0.0161 - val_loss: 0.0014 - val_mae: 0.0289
#
# Seed 67089 → MAE = 87.87, RMSE = 103.27

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ==============================
# LSTM–EGARCH results (10 seeds)
# ==============================

# batch of 10 (earlier)
lstm_mae_2 = np.array([82.34, 102.37, 157.16, 190.59, 67.52, 121.15, 58.84, 84.00, 59.55, 60.21])
lstm_rmse_2 = np.array([111.72, 132.16, 194.52, 229.84, 87.89, 155.64, 72.73, 113.29, 72.70, 78.54])


lstm_mae = np.concatenate([lstm_mae])
lstm_rmse = np.concatenate([lstm_rmse])

# ==============================
# BiLSTM–EGARCH results (10 seeds)
# ==============================

# batch of 10 (just now)
bilstm_mae = np.array([92.12, 56.22, 125.14, 53.60, 81.49, 65.76, 82.20, 56.64, 52.79, 87.87])
bilstm_rmse = np.array([110.95, 69.80, 143.49, 68.45, 97.53, 80.98, 111.84, 74.58, 65.98, 103.27])

bilstm_mae = np.concatenate([bilstm_mae])
bilstm_rmse = np.concatenate([bilstm_rmse])

# %%
def summarize_model(name, mae_arr, rmse_arr):
    return {
        "Model": name,
        "MAE_mean": mae_arr.mean(),
        "MAE_std": mae_arr.std(),
        "MAE_min": mae_arr.min(),
        "MAE_max": mae_arr.max(),
        "RMSE_mean": rmse_arr.mean(),
        "RMSE_std": rmse_arr.std(),
        "RMSE_min": rmse_arr.min(),
        "RMSE_max": rmse_arr.max(),
    }

lstm_summary   = summarize_model("LSTM_EGARCH", lstm_mae, lstm_rmse)
bilstm_summary = summarize_model("BiLSTM_EGARCH", bilstm_mae, bilstm_rmse)

df_summary = pd.DataFrame([lstm_summary, bilstm_summary])
print(df_summary)
# Out:
#            Model  MAE_mean    MAE_std  MAE_min  MAE_max  RMSE_mean   RMSE_std  \
# 0    LSTM_EGARCH   104.159  45.766408    51.21   207.18    131.690  54.350937
# 1  BiLSTM_EGARCH    75.383  21.889824    52.79   125.14     92.687  23.887658
#
#    RMSE_min  RMSE_max
# 0     66.48    252.05
# 1     65.98    143.49

# %%
plt.figure(figsize=(10,4))

# MAE boxplot
plt.subplot(1, 2, 1)
plt.boxplot([lstm_mae, bilstm_mae], labels=["LSTM_EGARCH", "BiLSTM_EGARCH"])
plt.title("MAE distribution across seeds")
plt.ylabel("MAE")

# RMSE boxplot
plt.subplot(1, 2, 2)
plt.boxplot([lstm_rmse, bilstm_rmse], labels=["LSTM_EGARCH", "BiLSTM_EGARCH"])
plt.title("RMSE distribution across seeds")
plt.ylabel("RMSE")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1455680071.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([lstm_mae, bilstm_mae], labels=["LSTM_EGARCH", "BiLSTM_EGARCH"])
# /tmp/ipython-input-1455680071.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([lstm_rmse, bilstm_rmse], labels=["LSTM_EGARCH", "BiLSTM_EGARCH"])

# %%
# Best seeds by MAE (within the 20 values you gave)
best_lstm_idx = np.argmin(lstm_mae)
best_bilstm_idx = np.argmin(bilstm_mae)

print("Best LSTM-EGARCH run:")
print("  MAE  =", lstm_mae[best_lstm_idx])
print("  RMSE =", lstm_rmse[best_lstm_idx])

print("\nBest BiLSTM-EGARCH run:")
print("  MAE  =", bilstm_mae[best_bilstm_idx])
print("  RMSE =", bilstm_rmse[best_bilstm_idx])
# Out:
# Best LSTM-EGARCH run:
#   MAE  = 51.21
#   RMSE = 66.48
#
# Best BiLSTM-EGARCH run:
#   MAE  = 52.79
#   RMSE = 65.98

# %%
# ============================================
# 0. IMPORTS
# ============================================
import numpy as np
import pandas as pd
import os, random

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense
from tensorflow.keras.optimizers import Adam


# ============================================
# 1. CONFIG
# ============================================
window_size = 14                 # chosen from your analysis
train_ratio = 0.8
val_ratio   = 0.1                # test will be 0.1
BEST_SEED   = 83472               # best BiLSTM-EGARCH seed from your experiments

# ============================================
# 2. PREPARE DATA (Gold_df)
#  - Assumes Gold_df has columns: Date (optional), Close, Vol, log_egarch_vol_ewm
# ============================================

# If Date is a column, set as index
if 'Date' in Gold_df.columns:
    Gold_df['Date'] = pd.to_datetime(Gold_df['Date'])
    Gold_df = Gold_df.set_index('Date')

Gold_df = Gold_df.sort_index()

# Features used in the model
feature_cols = ['Close', 'Vol', 'log_egarch_vol_ewm']

# Clean modeling DataFrame
df_model = Gold_df[feature_cols].dropna().copy()
print("Data used for modeling:", df_model.shape)
print(df_model.head())

# ============================================
# 3. TRAIN / VALIDATION / TEST SPLIT (TIME-BASED)
# ============================================
n = len(df_model)
train_end = int(n * train_ratio)
val_end   = int(n * (train_ratio + val_ratio))

print("Total rows:", n)
print("Train end index:", train_end)
print("Val end index  :", val_end)

# Overlap window_size rows for val/test so we can build sequences
train_raw = df_model.iloc[:train_end].values
val_raw   = df_model.iloc[train_end - window_size : val_end].values
test_raw  = df_model.iloc[val_end - window_size :].values

print("Train raw:", train_raw.shape)
print("Val raw  :", val_raw.shape)
print("Test raw :", test_raw.shape)

# ============================================
# 4. SCALING (FEATURES + TARGET)
# ============================================

# Feature scaler (all features, including Close)
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(train_raw)
X_val_scaled   = X_scaler.transform(val_raw)
X_test_scaled  = X_scaler.transform(test_raw)

# Target scaler (Close only, column 0)
y_scaler = MinMaxScaler()
close_train = train_raw[:, 0].reshape(-1, 1)
close_val   = val_raw[:, 0].reshape(-1, 1)
close_test  = test_raw[:, 0].reshape(-1, 1)

y_train_scaled_full = y_scaler.fit_transform(close_train)
y_val_scaled_full   = y_scaler.transform(close_val)
y_test_scaled_full  = y_scaler.transform(close_test)

# ============================================
# 5. CREATE SEQUENCES
# ============================================
def create_sequences(X_data, y_data, window_size=14):
    """
    X_data: (N, n_features)
    y_data: (N, 1)
    Returns:
      X: (num_samples, window_size, n_features)
      y: (num_samples, 1)
    """
    X, y = [], []
    for i in range(window_size, len(X_data)):
        X.append(X_data[i-window_size:i])
        y.append(y_data[i])
    return np.array(X), np.array(y)

X_tr, y_tr = create_sequences(X_train_scaled, y_train_scaled_full, window_size)
X_val, y_val = create_sequences(X_val_scaled, y_val_scaled_full, window_size)
X_te, y_te = create_sequences(X_test_scaled, y_test_scaled_full, window_size)

print("Train seq:", X_tr.shape, y_tr.shape)
print("Val seq  :", X_val.shape, y_val.shape)
print("Test seq :", X_te.shape, y_te.shape)

# ============================================
# 6. BILSTM-EGARCH MODEL (SIMPLE, VALIDATED VERSION)
# ============================================
def build_bilstm_model(input_shape, units=64, dense_units=32, lr=1e-3):
    model = Sequential([
        Bidirectional(LSTM(units, return_sequences=False),
                      input_shape=input_shape),
        Dense(dense_units, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=lr),
                  loss='mse',
                  metrics=['mae'])
    return model

def train_bilstm_once(
    X_tr, y_tr, X_val, y_val, X_te, y_te, y_scaler,
    epochs=30, batch_size=32, seed=None,
    units=64, dense_units=32, lr=1e-3
):
    # Clear previous graph
    tf.keras.backend.clear_session()

    # Seed everything for reproducibility
    if seed is not None:
        seed = int(seed)
        np.random.seed(seed)
        random.seed(seed)
        tf.random.set_seed(seed)
        os.environ["PYTHONHASHSEED"] = str(seed)
        os.environ["TF_DETERMINISTIC_OPS"] = "1"

    input_shape = (X_tr.shape[1], X_tr.shape[2])
    model = build_bilstm_model(input_shape, units=units,
                               dense_units=dense_units, lr=lr)

    print(model.summary())

    history = model.fit(
        X_tr, y_tr,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        shuffle=False,
        verbose=1
    )

    # Predict on test set (scaled)
    y_pred_scaled = model.predict(X_te, verbose=0)
    # Inverse transform to original Close scale
    y_pred = y_scaler.inverse_transform(y_pred_scaled)
    y_true = y_scaler.inverse_transform(y_te)

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    print(f"\nFINAL TEST MAE  : {mae:.4f}")
    print(f"FINAL TEST RMSE : {rmse:.4f}")

    return model, mae, rmse, y_true, y_pred

# ============================================
# 7. TRAIN FINAL MODEL WITH BEST SEED
# ============================================
best_model, best_mae, best_rmse, y_true, y_pred = train_bilstm_once(
    X_tr, y_tr,
    X_val, y_val,
    X_te, y_te,
    y_scaler,
    epochs=30,
    batch_size=32,
    seed=BEST_SEED,
    units=64,
    dense_units=32,
    lr=1e-3
)

print("Best seed:", BEST_SEED)
print("Best-model MAE :", best_mae)
print("Best-model RMSE:", best_rmse)

# ============================================
# 8. OPTIONAL: ENSEMBLE OF SEEDS (IF YOU WANT)
# ============================================
# Uncomment this block if you want to run an ensemble.

"""
ensemble_seeds = [9792, 31545, 738]  # example: pick seeds you liked
ensemble_preds = []
ensemble_metrics = []

for s in ensemble_seeds:
    print(f"\n===== Training ensemble member (seed={s}) =====")
    model_e, mae_e, rmse_e, y_true_e, y_pred_e = train_bilstm_once(
        X_tr, y_tr, X_val, y_val, X_te, y_te, y_scaler,
        epochs=30, batch_size=32, seed=s
    )
    ensemble_preds.append(y_pred_e)
    ensemble_metrics.append((mae_e, rmse_e))

ensemble_preds = np.stack(ensemble_preds, axis=0)  # (n_models, n_test, 1)
ensemble_metrics = np.array(ensemble_metrics)

print("\nIndividual ensemble metrics (MAE, RMSE):")
print(ensemble_metrics)
print("Mean MAE :", ensemble_metrics[:,0].mean())
print("Mean RMSE:", ensemble_metrics[:,1].mean())

# Mean ensemble prediction
ensemble_mean_pred = ensemble_preds.mean(axis=0)
ensemble_mae = mean_absolute_error(y_true, ensemble_mean_pred)
ensemble_rmse = np.sqrt(mean_squared_error(y_true, ensemble_mean_pred))
print("\nEnsemble mean prediction MAE :", ensemble_mae)
print("Ensemble mean prediction RMSE:", ensemble_rmse)
"""

# ============================================
# 9. 1-DAY AHEAD FORECAST FUNCTION
# ============================================
def forecast_next_day_close(model, Gold_df, feature_cols, X_scaler, y_scaler, window_size=14):
    """
    Uses the last `window_size` rows of Gold_df[feature_cols] to predict
    the next-day Close price.
    """
    df_latest = Gold_df[feature_cols].dropna().copy()
    latest_features = df_latest.tail(window_size).values

    # Scale with training feature scaler
    latest_scaled = X_scaler.transform(latest_features)

    # Reshape to (1, window_size, n_features)
    X_input = latest_scaled.reshape(1, window_size, -1)

    # Predict scaled Close
    y_pred_scaled = model.predict(X_input, verbose=0)

    # Inverse transform to original Close
    y_pred = y_scaler.inverse_transform(y_pred_scaled)

    return float(y_pred[0, 0])

# Example: get next-day forecast from best_model
next_close_pred = forecast_next_day_close(
    best_model,
    Gold_df,
    feature_cols,
    X_scaler,
    y_scaler,
    window_size=window_size
)

print("\nPredicted next-day Close:", next_close_pred)
# Out:
# Data used for modeling: (2039, 3)
#              Close       Vol  log_egarch_vol_ewm
# Date
# 2018-01-03  1318.5  353460.0           -0.533594
# 2018-01-04  1321.6  369850.0           -0.535741
# 2018-01-05  1322.3  330230.0           -0.537482
# 2018-01-08  1320.4  246090.0           -0.545447
# 2018-01-09  1313.7  333530.0           -0.555655
# Total rows: 2039
# Train end index: 1631
# Val end index  : 1835
# Train raw: (1631, 3)
# Val raw  : (218, 3)
# Test raw : (218, 3)
# Train seq: (1617, 14, 3) (1617, 1)
# Val seq  : (204, 14, 3) (204, 1)
# Test seq : (204, 14, 3) (204, 1)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 128)            │        34,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,977 (152.25 KB)
#  Trainable params: 38,977 (152.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0069 - mae: 0.0672 - val_loss: 0.0051 - val_mae: 0.0594
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0157 - mae: 0.1074 - val_loss: 0.0046 - val_mae: 0.0575
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0142 - mae: 0.0955 - val_loss: 0.0031 - val_mae: 0.0460
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - mae: 0.0310 - val_loss: 0.0030 - val_mae: 0.0446
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.8692e-04 - mae: 0.0239 - val_loss: 0.0041 - val_mae: 0.0515
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.0115e-04 - mae: 0.0210 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013 - mae: 0.0273 - val_loss: 0.0018 - val_mae: 0.0353
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0017 - mae: 0.0341 - val_loss: 0.0017 - val_mae: 0.0339
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0018 - val_mae: 0.0347
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0016 - val_mae: 0.0324
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1178e-04 - mae: 0.0229 - val_loss: 0.0015 - val_mae: 0.0313
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.9730e-04 - mae: 0.0215 - val_loss: 0.0015 - val_mae: 0.0307
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.4066e-04 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8473e-04 - mae: 0.0216 - val_loss: 0.0014 - val_mae: 0.0292
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4765e-04 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0289
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.6473e-04 - mae: 0.0212 - val_loss: 0.0013 - val_mae: 0.0285
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4664e-04 - mae: 0.0206 - val_loss: 0.0013 - val_mae: 0.0282
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6715e-04 - mae: 0.0209 - val_loss: 0.0013 - val_mae: 0.0279
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.7207e-04 - mae: 0.0213 - val_loss: 0.0013 - val_mae: 0.0276
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.0591e-04 - mae: 0.0214 - val_loss: 0.0013 - val_mae: 0.0274
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.2152e-04 - mae: 0.0220 - val_loss: 0.0013 - val_mae: 0.0271
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5672e-04 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0267
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5512e-04 - mae: 0.0224 - val_loss: 0.0012 - val_mae: 0.0262
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.8313e-04 - mae: 0.0223 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.8669e-04 - mae: 0.0226 - val_loss: 0.0012 - val_mae: 0.0263
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.7423e-04 - mae: 0.0223 - val_loss: 0.0013 - val_mae: 0.0278
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.2812e-04 - mae: 0.0217 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.1638e-04 - mae: 0.0197 - val_loss: 0.0017 - val_mae: 0.0340
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.6807e-04 - mae: 0.0176 - val_loss: 0.0016 - val_mae: 0.0331
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 4.9844e-04 - mae: 0.0151 - val_loss: 0.0011 - val_mae: 0.0259
#
# FINAL TEST MAE  : 52.7919
# FINAL TEST RMSE : 65.9844
# Best seed: 83472
# Best-model MAE : 52.79185508578435
# Best-model RMSE: 65.98441782327622
#
# Predicted next-day Close: 4217.19482421875

# %%
best_model.save("BiLSTM_EGARCH_seed83472.h5")
print("Model saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved!

# %%
from sklearn.metrics import r2_score

# y_true and y_pred are already in original price scale
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print("Test MAE :", mae)
print("Test RMSE:", rmse)
print("Test R^2 :", r2)
# Out:
# Test MAE : 52.79185508578435
# Test RMSE: 65.98441782327622
# Test R^2 : 0.9694176640666385

# %%
import matplotlib.pyplot as plt
N = 200  # last 200 days of test set

plt.figure(figsize=(10, 5))
plt.plot(y_true[-N:], label="True", linewidth=1)
plt.plot(y_pred[-N:], label="Predicted", linewidth=1)
plt.title("Gold – True vs Predicted (BiLSTM–EGARCH)")
plt.xlabel("Time (test index)")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

# %%
residuals = (y_true - y_pred).ravel()

plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.title("Residuals on Test Set")
plt.xlabel("Time (test index)")
plt.ylabel("Error (True - Pred)")
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Use the same test sequences you already created: X_te, y_te
# X_te shape: (n_test, 14, 3)

# Aggregate each 14-day window with a simple mean over time
X_te_summary = X_te.mean(axis=1)   # shape: (n_test, 3)
print("X_te_summary shape:", X_te_summary.shape)

# Get the BiLSTM predictions (this is what we want to explain)
y_pred_scaled = best_model.predict(X_te, verbose=0)
y_pred = y_scaler.inverse_transform(y_pred_scaled)  # back to price scale
y_pred = y_pred.ravel()
print("y_pred shape:", y_pred.shape)
# Out:
# X_te_summary shape: (204, 3)
# y_pred shape: (204,)

# %%
from sklearn.ensemble import GradientBoostingRegressor

surrogate = GradientBoostingRegressor(random_state=0)
surrogate.fit(X_te_summary, y_pred)

print("Surrogate R^2 on test summary features:",
      surrogate.score(X_te_summary, y_pred))
# Out:
# Surrogate R^2 on test summary features: 0.9997196922825123

# %%
import shap

# SHAP expects 2D: (samples, features) – that's exactly what X_te_summary is.
background = X_te_summary[:50]       # a subset as background
X_explain  = X_te_summary            # explain all test samples or a subset

explainer = shap.KernelExplainer(surrogate.predict, background)
shap_values = explainer.shap_values(X_explain, nsamples=200)

print("SHAP shape:", np.array(shap_values).shape)  # (n_samples, 3)
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]
# SHAP shape: (204, 3)

# %%
abs_shap = np.abs(shap_values)
mean_abs_shap = abs_shap.mean(axis=0)  # (3,)

for name, val in zip(['Close_mean_14d', 'Vol_mean_14d', 'EGARCH_mean_14d'],
                     mean_abs_shap):
    print(f"{name}: mean |SHAP| = {val:.4f}")
# Out:
# Close_mean_14d: mean |SHAP| = 440.8654
# Vol_mean_14d: mean |SHAP| = 5.4983
# EGARCH_mean_14d: mean |SHAP| = 13.8967
